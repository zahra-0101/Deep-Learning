# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')
from subprocess import check_output
import sys
print (sys.argv)
# print(check_output(['python', 'py2.py', '-i', 'test.txt']))
# Any results you write to the current directory are saved as output.
# Out:
# ['d:\\repositories\\myenvdeeplearning\\lib\\site-packages\\ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9013', '--control=9011', '--hb=9010', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"ea7f31a9-2e15-481d-aabd-de52ef9c4710"', '--shell=9012', '--transport="tcp"', '--iopub=9014', '--f=c:\\Users\\Emilie\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-8108SOFj403RxzBH.json']

# %%
# load data set
x_l = np.load('X.npy')
Y_l = np.load('Y.npy')
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[260].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# Join a sequence of arrays along an row axis.
X = np.concatenate((x_l[204:409], x_l[822:1027] ), axis=0) # from 0 to 204 is zero sign and from 205 to 410 is one sign 
z = np.zeros(205)
o = np.ones(205)
Y = np.concatenate((z, o), axis=0).reshape(X.shape[0],1)
print("X shape: " , X.shape)
print("Y shape: " , Y.shape)
# Out:
# X shape:  (410, 64, 64)
# Y shape:  (410, 1)

# %%
# Then lets create x_train, y_train, x_test, y_test arrays
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=42)
number_of_train = X_train.shape[0]
number_of_test = X_test.shape[0]

# %%
X_train_flatten = X_train.reshape(number_of_train,X_train.shape[1]*X_train.shape[2])
X_test_flatten = X_test .reshape(number_of_test,X_test.shape[1]*X_test.shape[2])
print("X train flatten",X_train_flatten.shape)
print("X test flatten",X_test_flatten.shape)
# Out:
# X train flatten (348, 4096)
# X test flatten (62, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_train = Y_train.T
y_test = Y_test.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (4096, 348)
# x test:  (4096, 62)
# y train:  (1, 348)
# y test:  (1, 62)

# %%
# short description and example of definition (def)
def dummy(parameter):
    dummy_parameter = parameter + 5
    return dummy_parameter
result = dummy(3)     # result = 8

# lets initialize parameters
# So what we need is dimension 4096 that is number of pixels as a parameter for our initialize method(def)
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w, b

# %%
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head
# Out:
# 0.5

# %%
def forward_propagation(w,b,x_train,y_train):
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z) # probabilistic 0-1
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    return cost

# %%
def forward_backward_propagation(w,b,x_train,y_train):
    # forward propagation
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z)
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    # backward propagation
    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1] # x_train.shape[1]  is for scaling
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]                 # x_train.shape[1]  is for scaling
    gradients = {"derivative_weight": derivative_weight,"derivative_bias": derivative_bias}
    return cost,gradients

# %%
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    index = []
    # updating(learning) parameters is number_of_iterarion times
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        # lets update
        w = w - learning_rate * gradients["derivative_weight"]
        b = b - learning_rate * gradients["derivative_bias"]
        if i % 10 == 0:
            cost_list2.append(cost)
            index.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    plt.plot(index,cost_list2)
    plt.xticks(index,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    return parameters, gradients, cost_list

# %%
def predict(w,b,x_test):
    # x_test is a input for forward propagation
    z = sigmoid(np.dot(w.T,x_test)+b)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(z.shape[1]):
        if z[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %%
def logistic_regression(x_train, y_train, x_test, y_test, learning_rate ,  num_iterations):
    # initialize
    dimension =  x_train.shape[0]  # that is 4096
    w,b = initialize_weights_and_bias(dimension)
    # do not change learning rate
    parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate,num_iterations)
    
    y_prediction_test = predict(parameters["weight"],parameters["bias"],x_test)
    y_prediction_train = predict(parameters["weight"],parameters["bias"],x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.01, num_iterations = 150)
# Out:
# Cost after iteration 0: 14.014222
# Cost after iteration 10: 2.544689
# Cost after iteration 20: 2.577950
# Cost after iteration 30: 2.397999
# Cost after iteration 40: 2.185019
# Cost after iteration 50: 1.968348
# Cost after iteration 60: 1.754195
# Cost after iteration 70: 1.535079
# Cost after iteration 80: 1.297567
# Cost after iteration 90: 1.031919
# Cost after iteration 100: 0.737019
# Cost after iteration 110: 0.441355
# Cost after iteration 120: 0.252278
# Cost after iteration 130: 0.205168
# Cost after iteration 140: 0.196168
# train accuracy: 92.816091954023 %
# test accuracy: 93.54838709677419 %

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression(random_state = 42,max_iter= 150)
print("test accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_test.T, y_test.T)))
print("train accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_train.T, y_train.T)))
# Out:
# test accuracy: 0.967741935483871
# train accuracy: 1.0

# %%
def initialize_parameters_and_layer_sizes_NN(x_train, y_train):
    parameters = {"weight1": np.random.randn(3,x_train.shape[0]) * 0.1,
                  "bias1": np.zeros((3,1)),
                  "weight2": np.random.randn(y_train.shape[0],3) * 0.1,
                  "bias2": np.zeros((y_train.shape[0],1))}
    return parameters

# %%
def forward_propagation_NN(x_train, parameters):

    Z1 = np.dot(parameters["weight1"],x_train) +parameters["bias1"]
    A1 = np.tanh(Z1)
    Z2 = np.dot(parameters["weight2"],A1) + parameters["bias2"]
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
def compute_cost_NN(A2, Y, parameters):
    logprobs = np.multiply(np.log(A2),Y)
    cost = -np.sum(logprobs)/Y.shape[1]
    return cost

# %%
def backward_propagation_NN(parameters, cache, X, Y):

    dZ2 = cache["A2"]-Y
    dW2 = np.dot(dZ2,cache["A1"].T)/X.shape[1]
    db2 = np.sum(dZ2,axis =1,keepdims=True)/X.shape[1]
    dZ1 = np.dot(parameters["weight2"].T,dZ2)*(1 - np.power(cache["A1"], 2))
    dW1 = np.dot(dZ1,X.T)/X.shape[1]
    db1 = np.sum(dZ1,axis =1,keepdims=True)/X.shape[1]
    grads = {"dweight1": dW1,
             "dbias1": db1,
             "dweight2": dW2,
             "dbias2": db2}
    return grads

# %%
def update_parameters_NN(parameters, grads, learning_rate = 0.01):
    parameters = {"weight1": parameters["weight1"]-learning_rate*grads["dweight1"],
                  "bias1": parameters["bias1"]-learning_rate*grads["dbias1"],
                  "weight2": parameters["weight2"]-learning_rate*grads["dweight2"],
                  "bias2": parameters["bias2"]-learning_rate*grads["dbias2"]}
    
    return parameters

# %%
def predict_NN(parameters,x_test):
    # x_test is a input for forward propagation
    A2, cache = forward_propagation_NN(x_test,parameters)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(A2.shape[1]):
        if A2[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %%
def two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations):
    cost_list = []
    index_list = []
    #initialize parameters and layer sizes
    parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

    for i in range(0, num_iterations):
         # forward propagation
        A2, cache = forward_propagation_NN(x_train,parameters)
        # compute cost
        cost = compute_cost_NN(A2, y_train, parameters)
         # backward propagation
        grads = backward_propagation_NN(parameters, cache, x_train, y_train)
         # update parameters
        parameters = update_parameters_NN(parameters, grads)
        
        if i % 100 == 0:
            cost_list.append(cost)
            index_list.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    plt.plot(index_list,cost_list)
    plt.xticks(index_list,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    
    # predict
    y_prediction_test = predict_NN(parameters,x_test)
    y_prediction_train = predict_NN(parameters,x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    return parameters

parameters = two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations=2500)
# Out:
# Cost after iteration 0: 0.400161
# Cost after iteration 100: 0.293021
# Cost after iteration 200: 0.243775
# Cost after iteration 300: 0.192429
# Cost after iteration 400: 0.152045
# Cost after iteration 500: 0.122330
# Cost after iteration 600: 0.100969
# Cost after iteration 700: 0.085481
# Cost after iteration 800: 0.073819
# Cost after iteration 900: 0.064641
# Cost after iteration 1000: 0.057171
# Cost after iteration 1100: 0.050966
# Cost after iteration 1200: 0.045751
# Cost after iteration 1300: 0.041318
# Cost after iteration 1400: 0.037494
# Cost after iteration 1500: 0.034124
# Cost after iteration 1600: 0.031089
# Cost after iteration 1700: 0.028349
# Cost after iteration 1800: 0.025935
# Cost after iteration 1900: 0.023865
# Cost after iteration 2000: 0.022097
# Cost after iteration 2100: 0.020566
# Cost after iteration 2200: 0.019209
# Cost after iteration 2300: 0.017978
# Cost after iteration 2400: 0.016840
# train accuracy: 99.71264367816092 %
# test accuracy: 95.16129032258064 %

# %%
x_train, x_test, y_train, y_test = x_train.T, x_test.T, y_train.T, y_test.T

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential # initialize neural network library
from keras.layers import Dense # build our layers library
def build_classifier():
    classifier = Sequential() # initialize neural network
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.5172
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5431
# Epoch 3/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5431
# Epoch 4/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5431
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5431
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5431
# Epoch 7/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5431
# Epoch 8/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5431
# Epoch 9/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5431
# Epoch 10/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5431
# Epoch 11/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5431
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5431
# Epoch 13/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.5431
# Epoch 14/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.5431
# Epoch 15/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6916 - accuracy: 0.5431
# Epoch 16/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6915 - accuracy: 0.5431
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6914 - accuracy: 0.5431
# Epoch 18/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.5431
# Epoch 19/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6912 - accuracy: 0.5431
# Epoch 20/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6912 - accuracy: 0.5431
# Epoch 21/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6912 - accuracy: 0.5431
# Epoch 22/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.5431
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.5431
# Epoch 24/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.5431
# Epoch 25/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 26/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 27/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5431
# Epoch 28/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5431
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5431
# Epoch 30/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5431
# Epoch 31/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5431
# Epoch 32/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6904 - accuracy: 0.5431
# Epoch 33/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6904 - accuracy: 0.5431
# Epoch 34/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 35/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 36/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 37/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5431
# Epoch 38/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 39/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 40/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 41/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.5431
# Epoch 42/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 43/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 44/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 45/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 46/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6901 - accuracy: 0.5431
# Epoch 47/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 49/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5431
# Epoch 50/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 51/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 54/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 56/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5431
# Epoch 57/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 61/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 62/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 64/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 65/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 67/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 68/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 69/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 70/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 71/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 72/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 73/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 76/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 78/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 79/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 80/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 81/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.5431
# Epoch 82/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 83/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 84/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 85/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 86/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 87/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 88/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 90/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 92/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5431
# Epoch 93/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 96/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 98/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 99/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5431
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7068 - accuracy: 0.4310
# Epoch 1/100
# 8/8 [==============================] - 1s 3ms/step - loss: 0.6932 - accuracy: 0.4784
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5216
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5216
# Epoch 4/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5216
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5216
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5216
# Epoch 7/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5216
# Epoch 8/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5216
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5216
# Epoch 10/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5216
# Epoch 11/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5216
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5216
# Epoch 13/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5216
# Epoch 14/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 15/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 16/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5216
# Epoch 18/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 19/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 20/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 21/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 24/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 25/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 26/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 27/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 28/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 30/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 31/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5216
# Epoch 32/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 33/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 34/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 35/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 36/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 37/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 38/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 39/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5216
# Epoch 40/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 41/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 42/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 43/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 44/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 45/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 46/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 47/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 49/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 50/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 51/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 54/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 56/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 57/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 61/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 62/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 65/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 67/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 68/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 70/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 71/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 73/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 76/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 78/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 79/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 80/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 81/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 82/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 84/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 85/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 86/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 87/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 88/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 90/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 93/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 96/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 98/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5216
# Epoch 99/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5216
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5216
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6983 - accuracy: 0.4397
# Epoch 1/100
# 8/8 [==============================] - 1s 3ms/step - loss: 0.6934 - accuracy: 0.5129
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.4957
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.4957
# Epoch 4/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.4957
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.4957
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.4957
# Epoch 7/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.4957
# Epoch 8/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.4957
# Epoch 9/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6826 - accuracy: 0.4957
# Epoch 10/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6752 - accuracy: 0.5216
# Epoch 11/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6653 - accuracy: 0.6078
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6501 - accuracy: 0.6853
# Epoch 13/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.5647
# Epoch 14/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6070 - accuracy: 0.6897
# Epoch 15/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5861 - accuracy: 0.7500
# Epoch 16/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5582 - accuracy: 0.7371
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5386 - accuracy: 0.7888
# Epoch 18/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5263 - accuracy: 0.7629
# Epoch 19/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5168 - accuracy: 0.8707
# Epoch 20/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5060 - accuracy: 0.8405
# Epoch 21/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4803 - accuracy: 0.8233
# Epoch 22/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.9138
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.8362
# Epoch 24/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4489 - accuracy: 0.9095
# Epoch 25/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4432 - accuracy: 0.8578
# Epoch 26/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4304 - accuracy: 0.9095
# Epoch 27/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4106 - accuracy: 0.9138
# Epoch 28/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4011 - accuracy: 0.9224
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4073 - accuracy: 0.9353
# Epoch 30/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3932 - accuracy: 0.9224
# Epoch 31/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3819 - accuracy: 0.9440
# Epoch 32/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.9052
# Epoch 33/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.9009
# Epoch 34/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3656 - accuracy: 0.9440
# Epoch 35/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3549 - accuracy: 0.9526
# Epoch 36/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3495 - accuracy: 0.9612
# Epoch 37/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3408 - accuracy: 0.9483
# Epoch 38/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3336 - accuracy: 0.9655
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3284 - accuracy: 0.9483
# Epoch 40/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3224 - accuracy: 0.9569
# Epoch 41/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.9698
# Epoch 42/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.9526
# Epoch 43/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3219 - accuracy: 0.9612
# Epoch 44/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.9612
# Epoch 45/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3060 - accuracy: 0.9741
# Epoch 46/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.9655
# Epoch 47/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2906 - accuracy: 0.9612
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2945 - accuracy: 0.9741
# Epoch 49/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2799 - accuracy: 0.9698
# Epoch 50/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2817 - accuracy: 0.9612
# Epoch 51/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2875 - accuracy: 0.9741
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2747 - accuracy: 0.9784
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2692 - accuracy: 0.9741
# Epoch 54/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2602 - accuracy: 0.9655
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2627 - accuracy: 0.9784
# Epoch 56/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.9828
# Epoch 57/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2431 - accuracy: 0.9784
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2449 - accuracy: 0.9871
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.9784
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2302 - accuracy: 0.9828
# Epoch 61/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2260 - accuracy: 0.9828
# Epoch 62/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2217 - accuracy: 0.9784
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2193 - accuracy: 0.9828
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.9828
# Epoch 65/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2034 - accuracy: 0.9828
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9741
# Epoch 67/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.9871
# Epoch 68/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1915 - accuracy: 0.9828
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1884 - accuracy: 0.9871
# Epoch 70/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9828
# Epoch 71/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9828
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9828
# Epoch 73/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1741 - accuracy: 0.9871
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1983 - accuracy: 0.9784
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1761 - accuracy: 0.9871
# Epoch 76/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.9871
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9871
# Epoch 78/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1588 - accuracy: 0.9871
# Epoch 79/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1572 - accuracy: 0.9914
# Epoch 80/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9871
# Epoch 81/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 0.9914
# Epoch 82/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9828
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1572 - accuracy: 0.9828
# Epoch 84/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1487 - accuracy: 0.9871
# Epoch 85/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9828
# Epoch 86/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9914
# Epoch 87/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9871
# Epoch 88/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.9914
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.9871
# Epoch 90/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9871
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9871
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1357 - accuracy: 0.9871
# Epoch 93/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9914
# Epoch 94/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9914
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9914
# Epoch 96/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9914
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1165 - accuracy: 0.9914
# Epoch 98/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9871
# Epoch 99/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1362 - accuracy: 0.9784
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.9784
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2008 - accuracy: 0.9310
# Accuracy mean: 0.6005747218926748
# Accuracy variance: 0.23369685567312323
